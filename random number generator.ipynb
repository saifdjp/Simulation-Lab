# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **Witchman/Hill**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
R = list()
N = [100,1000,5000]

# %%
for t in N:
    n=t
   
    z1=[12,7]
    u1=[]
    m1=16
    for i in range(2,n):
        new_z= (13*z1[i-1] + 11*z1[i-2] + 3)  % m1
        z1.append(new_z)
        u1_new = new_z/ m1
        u1.append(u1_new)

    #print(z1)
    #print(u1)

    z2= [3,5]
    u2= []
    m2=17
    for i in range(2,n):
        new_z2= (12*(z2[i-1]**2) + 13*z2[i-2])  %m2
        z2.append(new_z2)
        u2_new= new_z2 / m2
        u2.append(u2_new)
    #print(z2)
    #print(u2)

    z3 = [2,7]
    u3 = []
    m3 = 15
    for i in range(2,n):
        new_z3 = ( (z3[i-1]**3) + (z3[i-2]**2) ) % m3
        z3.append(new_z3)
        u3_new = new_z3 / m3
        u3.append(u3_new)


    u = []
    for i in range(0,n-2):
        u_new=u1[i]+ u2[i] +u3[i]
        u.append(u_new-int(u_new))

    print((u))  
    R.append(u)

# %%
print("In 100 random, there are ",str(len(set(R[0]))), "number of unique random.")
print("In 1000 random, there are ",str(len(set(R[1]))), "number of unique random.")
print("In 5000 random, there are ",str(len(set(R[2]))), "number of unique random.")

# %%
plt.figure(figsize=(60,20))
plt.bar(range(1000),u[:1000])
plt.xlabel("Instance")
plt.ylabel("Random Value")

# %% [markdown]
# # **Tausworthe**

# %%
r = 3
q = 5
l = 4

b = [1,1,1,1,1]

N = [100]    #Number of random to generate

# %%
for n in N:
    b = [1,1,1,1,1]
    no_of_bit = l*n                     # To get 'n' random we will need l*n bit
    
    for i in range(5,no_of_bit):
        new_b = (b[i-r]+b[i-q]) % 2
        b.append(new_b)
    z = list()
    for i in range(3,len(b),4):
        new_z = b[i-3:i+1]
        new_z= sum(np.array(new_z)*[8,4,2,1])
        z.append(new_z)
    print(z)
    
    plt.figure(figsize=(150,40))
    plt.bar(range(n),z)

# %%
len(b)

# %%
z = list()
for i in range(3,len(b),4):
    new_z = b[i-3:i+1]
    new_z= sum(np.array(new_z)*[8,4,2,1])
    z.append(new_z)
    #break

# %%
set(z)
